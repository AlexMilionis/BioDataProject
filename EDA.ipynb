# %%
import pandas as pd
import numpy as np
from ucimlrepo import fetch_ucirepo

# %%
# fetch dataset 
cdc_diabetes_health_indicators = fetch_ucirepo(id=891) 
cdc_diabetes_health_indicators.keys()
# Out:
# dict_keys(['data', 'metadata', 'variables'])

# %%
cdc_diabetes_health_indicators['data'].keys()
# Out:
# dict_keys(['ids', 'features', 'targets', 'original', 'headers'])

# %%
cdc_diabetes_health_indicators['data']
# Out:
# {'ids':             ID
#  0            0
#  1            1
#  2            2
#  3            3
#  4            4
#  ...        ...
#  253675  253675
#  253676  253676
#  253677  253677
#  253678  253678
#  253679  253679
#
#  [253680 rows x 1 columns],
#  'features':         HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
#  0            1         1          1   40       1       0
#  1            0         0          0   25       1       0
#  2            1         1          1   28       0       0
#  3            1         0          1   27       0       0
#  4            1         1          1   24       0       0
#  ...        ...       ...        ...  ...     ...     ...
#  253675       1         1          1   45       0       0
#  253676       1         1          1   18       0       0
#  253677       0         0          1   28       0       0
#  253678       1         0          1   23       0       0
#  253679       1         1          1   25       0       0
#
# ...

# %%
cdc_diabetes_health_indicators['metadata']
# Out:
# {'uci_id': 891,
#  'name': 'CDC Diabetes Health Indicators',
#  'repository_url': 'https://archive.ics.uci.edu/dataset/891/cdc+diabetes+health+indicators',
#  'data_url': 'https://archive.ics.uci.edu/static/public/891/data.csv',
#  'abstract': 'The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy. ',
#  'area': 'Health and Medicine',
#  'tasks': ['Classification'],
#  'characteristics': ['Tabular', 'Multivariate'],
#  'num_instances': 253680,
#  'num_features': 21,
#  'feature_types': ['Categorical', 'Integer'],
#  'demographics': ['Sex', 'Age', 'Education Level', 'Income'],
#  'target_col': ['Diabetes_binary'],
#  'index_col': ['ID'],
# ...

# %%
cdc_diabetes_health_indicators['variables']
# Out:
#                     name     role     type      demographic  \
# 0                     ID       ID  Integer             None
# 1        Diabetes_binary   Target   Binary             None
# 2                 HighBP  Feature   Binary             None
# 3               HighChol  Feature   Binary             None
# 4              CholCheck  Feature   Binary             None
# 5                    BMI  Feature  Integer             None
# 6                 Smoker  Feature   Binary             None
# 7                 Stroke  Feature   Binary             None
# 8   HeartDiseaseorAttack  Feature   Binary             None
# 9           PhysActivity  Feature   Binary             None
# 10                Fruits  Feature   Binary             None
# 11               Veggies  Feature   Binary             None
# 12     HvyAlcoholConsump  Feature   Binary             None
# 13         AnyHealthcare  Feature   Binary             None
# 14           NoDocbcCost  Feature   Binary             None
# ...

# %%
inputs = pd.DataFrame(cdc_diabetes_health_indicators.data.features)
inputs
# Out:
#         HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0            1         1          1   40       1       0
# 1            0         0          0   25       1       0
# 2            1         1          1   28       0       0
# 3            1         0          1   27       0       0
# 4            1         1          1   24       0       0
# ...        ...       ...        ...  ...     ...     ...
# 253675       1         1          1   45       0       0
# 253676       1         1          1   18       0       0
# 253677       0         0          1   28       0       0
# 253678       1         0          1   23       0       0
# 253679       1         1          1   25       0       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  ...  \
# 0                          0             0       0        1  ...
# 1                          0             1       0        0  ...
# 2                          0             0       1        0  ...
# ...

# %%
targets = pd.DataFrame(cdc_diabetes_health_indicators.data.targets).to_numpy().flatten()
print(f'Diabetics: {np.sum(targets)}')
print(f'non Diabetics: {len(targets)-np.sum(targets)}')
# Out:
# Diabetics: 35346
# non Diabetics: 218334
